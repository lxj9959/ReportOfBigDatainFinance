# %%
import pandas as pd

data = pd.read_csv('https://resources.lendingclub.com/LoanStats_2019Q1.csv.zip')
display(data.head())
data
# Out:
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\2042015420.py:3: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,123,124,125,126,127,128,129,130,131,132,133,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('https://resources.lendingclub.com/LoanStats_2019Q1.csv.zip')
# ...

# %% [markdown]
# 2.寻找和金融相关的数据集
# 我们还可以从以下数据源中获取与金融相关的数据集：
#
# Kaggle - https://www.kaggle.com/c/financial-fraud-detection/data
# FRED (Federal Reserve Economic Data) - https://fred.stlouisfed.org/
# IMF (International Monetary Fund) - https://www.imf.org/en/Data

# %% [markdown]
# 3.提供数据集的来源，描述，以及应用场景
# LendingClub数据集是从LendingClub网站上获取的，该网站是美国最大的P2P在线借贷平台之一。该数据集包含了超过100万笔贷款请求，每个请求包含了基本的财务和信用风险信息。
#
# 该数据集可以应用于风险评估、机器学习等领域。

# %%
data.to_csv('loan_data.csv', index=False)
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
import pandas as pd
data = pd.read_csv("loan_data.csv")
data
# Out:
#        Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                         settlement_term
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 115673                                                NaN
# 115674                                                NaN
# 115675                                                NaN
# 115676                                                NaN
# 115677                                                NaN
#
# [115678 rows x 1 columns]

# %%
import pandas as pd
data = pd.read_csv('loan_data.csv')
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115678 entries, 0 to 115677
# Data columns (total 1 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)  531 non-null    object
# dtypes: object(1)
# memory usage: 903.9+ KB
# None

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 115673     True
# 115674     True
# 115675     True
# 115676     True
# 115677     True
# Length: 115678, dtype: bool

# %%
data = data.drop_duplicates()   # data.drop_duplicates(inplace=True)
data
# Out:
#        Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                         settlement_term
# 1                                                     NaN
# 542                                                    24
# 2028                                                   19
# 2342                                                    7
# 2351                                                    1
# 3247                                                   12
# 3294                                                   18
# 4116                                                 17.0
# 4227                                                 24.0
# 5670                                                 12.0
# 6410                                                  6.0
# 6524                                                 10.0
# 7041                                                  1.0
# 7077                                                 18.0
# ...

# %%
data.isnull()
# Out:
#         Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                                   False
# 1                                                    True
# 542                                                 False
# 2028                                                False
# 2342                                                False
# 2351                                                False
# 3247                                                False
# 3294                                                False
# 4116                                                False
# 4227                                                False
# 5670                                                False
# 6410                                                False
# 6524                                                False
# 7041                                                False
# 7077                                                False
# ...

# %%
data.isnull().any()
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)    True
# dtype: bool

# %%
data.fillna(method='ffill')
# Out:
#        Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                         settlement_term
# 1                                         settlement_term
# 542                                                    24
# 2028                                                   19
# 2342                                                    7
# 2351                                                    1
# 3247                                                   12
# 3294                                                   18
# 4116                                                 17.0
# 4227                                                 24.0
# 5670                                                 12.0
# 6410                                                  6.0
# 6524                                                 10.0
# 7041                                                  1.0
# 7077                                                 18.0
# ...

# %%
data > data.mean() + 3*data.std()
# Out:
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\1936937772.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data > data.mean() + 3*data.std()
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\1936937772.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data > data.mean() + 3*data.std()
#         Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                                   False
# 1                                                   False
# 542                                                 False
# 2028                                                False
# ...

# %%
import numpy as np
data[data > data.mean() + 3*data.std()]=np.nan
# Out:
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\3482778741.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[data > data.mean() + 3*data.std()]=np.nan
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\3482778741.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data[data > data.mean() + 3*data.std()]=np.nan

# %%
data = data.fillna(data.mean())
# Out:
# C:\Users\69549\AppData\Local\Temp\ipykernel_21420\476127175.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())

# %%
import pandas as pd
df = pd.read_csv('loan_data.csv')
df.head(5)
# Out:
#   Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 0                                    settlement_term
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
def func(data, key_word):
    result = []
    for i in data['商品名称']:
        if key_word in i:
            result.append(1)
        else:
            result.append(0)
    return result
